# %%
# 10월 27일 시험(구두발표30,체크리스트70) 구두발표 30 base

# %% [markdown]
# # 프롤로그
# ### 시각화의 필요성
# - 데이터의 이해
# - 설득력
#
# ### 좋은 그래프
# - 청중들이 딱 보면 데이터를 이해함!
#
# ### 예시
# - 나이팅게일 로즈 다이어그램
# - 낙진님의 회사 연봉 협상 대작전

# %% [markdown]
# # 데이터 시각화
#
# - 데이터를 분석한 결과를 쉽게 이해할 수 있도록 표현한여 전달하는 것
#
# - 데이터 시각화가 필요한 이유
#     - 많은 양의 데이터를 한 눈에 살펴볼 수 있음
#     - 전문 지식이 없더라도 누구나 쉽게 데이터를 인지하고 사용할 수 있음
#     - 단순한 데이터의 요약이나 나열보다 더 정확한 데이터 분석 결과를 얻을 수 있음
#     - 단순한 데이터에서는 알 수 없었던 중요한 정보를 파악할 수 있음

# %% [markdown]
# - 더 좋은 시각화를 볼 줄 알게 되는것이 목표
# - 분석 보고서를 보는것... <b style="color:red">주식 유튜브를 봐라! 분석을 기깔나게 한다.</b>

# %% [markdown]
# - 파이썬의 시각화 라이브러리
#     - matplotlib ( 주력! )
#         - 파이썬에서 가장 많이 사용하는 시각화 라이브러리
#         - 판다스의 데이터프레임을 바로 시각화할 때도 내부적으로 matplotlib 을 사용
#         - 데이터 분석 이전의 데이터 이해를 위한 시각화 또는 데이터 분석 이후의 결과를 시각화하기 위해 사용
#     - seaborn (씨에본/씨본 : 어감이 그렇다, stand alone 확장팩 같은 녀석이다)
#         - matplotlib 을 기반으로 색 테마, 차트 기능 등을 추가해주는 라이브러리
#         - matplotlib 과 함께 사용하며 히트맵, 카운트 플롯 등을 제공
#     - folium (지도성애자 story)
#         - 지도 데이터를 이용하여 위치 정보를 시각화하는 라이브러리
#         - 자바스크립트 기반의 인터랙티브 그래프(상호작용이 된다!)를 그릴 수 있음
#     - plotly ( 3d로 빙글빙글 돌릴수있음 )
#         - 인터랙티브 그래프를 그려주는 라이브러리
#
#     - wordcloud
#         - 글자와글와글

# %% [markdown]
# # 시각화 단계
#
# 1. 시각화 라이브러리 불러오기
#     - 어떤 라이브러리 쓸꺼임?
# 2. x축, y축에 표시할 데이터 정하기
#     - 어떤 형태의 그림을 그리고 싶은지 정하고 들어가는 거에요~
# 3. plot() 함수에 데이터 입력하기
#     - 함수에 집중하는게 아니라! 데이터에 집중하세요
#     - 데이터 전처리가 더 중요합니다 ( 몽골대학생 : 나 대학생 논문 봐줘 돈. 가능 )
# 4. 그래프 보여주기

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# windows 용 한글 폰트 오류 해결
from matplotlib import font_manager, rc

font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc("font", family = font_name)

# %%
# mac os 용 한글 폰트 오류 해결 (실행하지마!!!!!)
# from matplotlib import rc
# rc("font", family = "AppleGothic")

# %%
# 발표할때는 한국말로 변경하는게 좋다

# %% [markdown]
# # 그래프란
#
# - 서로 연관성 있는 1개 또는 그 이상의 양에 대한 상대값을 도형으로 나타내느 것
#
# ### 그래프 사용시 반박시 니말맞음 하지만 일반적으로 사용하는 그래프가 있으니...(시인성 + 프로젝트의주제)에 따라달라짐
# - 데이터의 갯수, 종류에 따른 그래프의 종류
#     - 일변량(컬럼이 한개) :
#         - 연속형
#              - 히스토그램(histogram) : 분포를 나타낼때 기본적으로 사용
#              - 상자수염 그래프(boxplot)
#              - 바이올린 그래프(violin) : 창사용그래프에서 개선
#              - 커널 밀도 그래프(kernel density curve)
#              - 그외에도 많다요~
#
#         - 범주형
#             - 막대 그래프(bar chart)
#             - 파이 그래프(pie chart)
#     - 다변량(컬럼이 2개이상)
#         - 연속형
#               - 산점도(scatter plot) : 관계를 나타낼때 기본적으로 사용
#               - 선 그래프(line) : x축에는 시간이 주로 들어갈때 쓴다(시계열그래프예제)
#
#         - 범주형
#             - 모자이크 그래프(mosaic graph)
#             - Tree Map 그래프

# %% [markdown]
# ### 분석은 정답이 없어요!!!

# %% [markdown]
# # 기본 그래프

# %%
# 기본 시각화 문법
plt.plot([1,2,3,4]) # x값은 [0,1,2,3] 로 자동으로 입력됨
plt.ylabel("y축") # y축에 이름을 붙혔음
plt.xlabel("x축") # x축에 이름을 붙혔음
plt.show()

# %% [markdown]
# - 리스트의 값이 y값이라고 가정하고 x 값을 자동으로 생성 [0,1,2,3]

# %%
plt.plot([1, 2, 3, 4],[1, 4, 9, 16]) # x값은 [0,1,2,3] 로 자동으로 입력됨
# plot([x, y])
plt.show()

# %%
# 그려줬다가 결과물을 img 로 던지고 사라지는 툴이있다~?

# %%
# 이쁜이 작업
plt.plot([1,2,3,4],[1,4,9,16],"ro-") # red(r) + maker(o) + line(-) : 순서는 상관없는듯하다
plt.axis([0,6,0,20]) # 축의 범위 : 
plt.show()

# %% [markdown]
# - 낙도형 그래프등의 x 축이 긴 그래프를 x축을 축소 또는 y 축을 축소

# %% [markdown]
# ## 범례추가

# %%
# 데이터들...
plt.plot([1,2,3],[1,4,9])
plt.plot([1,2,3],[5,6,7]) # 1,5 ..

# 이거 꼭 적어...( 무슨 데이터인지 알기위한 메모라고 생각하셈 )
# 팀원들과 협업을 위해서도 꼭 적으세용...
plt.xlabel("시행횟수")
plt.ylabel("시간(초)")
plt.title("실험 결과")
plt.legend(["쥐","고양이"])
plt.show()

# %%
# 여러 개의 그래프 그리기

t = np.arange(0, 5, 0.2)

plt.plot(t, t, "r--", t, t ** 2, "bs", t, t**3, "g^")
# 읽을 때 
# t, t, "r--" 
# t, t ** 2, "bs" 
# t, t** 3 "g^"
# 이렇게 읽으셈
plt.show()

# %% [markdown]
# ### 명령어 체계 Colors, Line Styles, Markers

# %% [markdown]
# <img src="./image/matplotlib_set_marker.png">

# %% [markdown]
# # 테스또

# %%
# 2010년 부터 2018년까지 매년 수집한 데이터를 직선 그래프로 나타내기
# 직선은 빨간색 실선으로, 마커는 다이아몬드형으로 표시
# x축의 눈금은 년도를 나타내는 숫자로 표시
data = [102,105,108,129,166,170,181,182,182]
year = np.arange(2010,2019,1) # start, end-1, step  -linspace 로도 만들수있다~

plt.plot(year, data,"rD-") # x축 y 축 style 입력

plt.title("테스트!!!!")
plt.xlabel("년도")
plt.ylabel("키")

# 대괄호를 넣는이유 => 배열이라서... 아하!!!!!
# data 랑 x 자체는 배열이자나....

plt.show() # 보여줘~

# %% [markdown]
# # 그래프 영역 채우기

# %%
x = [1,2,3,4]
y = [1,4,9,16]

plt.plot(x,y)

plt.xlabel("x축")
plt.ylabel("y축")

# 영역 채우기 fill_between : 선과 x 축 사이 영역을 채워주는 함수
plt.fill_between(x[1:3], y[0:2], alpha = 0.5) 
# 첫 번째 인자 : x좌표
# 두 번째 인자 : 상한선


plt.show()

# %%
plt.plot(x, y)
plt.xlabel("x축")
plt.ylabel("y축")
plt.fill_betweenx(y[2:4], x[2:4], color="pink", alpha=0.5) # alpha : 투명도

plt.show()

# %% [markdown]
# # 두 그래프 사이 영역 채우기

# %%
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)

plt.xlabel("x축")
plt.ylabel("y축")
                # 데이터범위, 상한선, 하한선 
plt.fill_between(x[1:3], y1[1:3], y2[1:3], color = "lightgray", alpha = 0.4) 
plt.show()

# %%
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)

plt.xlabel("x축")
plt.ylabel("y축")
         # (1.9, 2), (1.9, 5), (3.1, 1), (3.1, 8) 이렇게 꼭지점 잡아서 채워줌 ( 순서 중요 )
plt.fill([1.9, 1.9, 3.1, 3.1], [2, 5, 11, 8], color = "lightgray", alpha = 0.4) 
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a **2, color="#e35f62", marker="|", linewidth = 0.2)
plt.plot(a, a **3, color="springgreen", marker="^", markersize = 9)
plt.show()

# %% [markdown]
# # 격자 설정

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a **2, color="#e35f62", marker="|", linewidth = 0.2)
plt.plot(a, a **3, color="springgreen", marker="^", markersize = 9)

plt.grid() # 격자다~
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color="#e35f62", marker="|", linewidth = 0.2)
plt.plot(a, a ** 3, color="springgreen", marker="^", markersize = 9)

plt.grid(axis = "y", color="#efef23", alpha = 1, linestyle="--") # y 격자다~
#plt.grid(axis = "both") # y 격자다~
#plt.grid(axis = "x") # y 격자다~
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color="#e35f62", marker="|", linewidth = 0.2)
plt.plot(a, a ** 3, color="springgreen", marker="^", markersize = 9)

# 눈금!
plt.xticks([0,1,2])
plt.yticks(np.arange(1,6), color="red")
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color="#e35f62", marker="|", linewidth = 0.2)
plt.plot(a, a ** 3, color="springgreen", marker="^", markersize = 9)

# labels 는 순서가 관련이 없어용 
# labels 는 데이터와 개수가 맞아야한다!
plt.xticks(np.arange(0,2,0.2), labels=["Jan", "", "Feb", "", "Mar","", "May","","June",""]) 
plt.yticks(np.arange(0,7), ("0","1GB","2GB","3GB","4GB","5GB","6GB"))
                                            # 탕후루
plt.tick_params(axis = "x", direction = "in", length = 13, pad = 6, labelsize = 14, labelcolor = "green", top = True)
plt.tick_params(axis = "y", direction = "inout", length = 10, pad = 15, labelsize = 12, width=2, color = "r", right = True)

plt.show()

# %% [markdown]
# # 제목 설정

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color="#e35f62", marker="|", linewidth = 0.2)
plt.plot(a, a ** 3, color="springgreen", marker="^", markersize = 9)

plt.grid(axis = "y", color = "gray", alpha = 0.5, linestyle = "--")
plt.tick_params(axis = "both", direction = "in", length = 3, pad = 6 , labelsize = 14)
plt.title("샘플 그래프1!!!!!!", loc="right", pad = 10) # loc = location, pad = padding

plt.show()

# %% [markdown]
# # 서브플롯

# %% [markdown]
# - figure : 그림 그릴 영역
# - subplot : 그 안쪽에 그림(눈금...등등) 2분할 4분할 가능

# %%
# 좋아하는 스타일 대로 짜주세용~

# %% [markdown]
# - plt.subplot(nrow, ncol, pos)

# %%
x = np.arange(1,10)
y1 = x * 5
y2 = x * 1

plt.subplot(2, 1, 1) # 2행 1열로 나눈 표의 값에 1포지션을 제어하겠다
plt.plot(x, y1) 

plt.subplot(2, 1, 2) # 2행 1열 나눈 표의 2포지션을 제어하겠다
plt.plot(x, y2)

plt.show()

# %%
x = np.arange(1,10)
y1 = x * 5
y2 = x * 1

plt.subplot(1, 2, 1) # 1행 1열로 1포지션
plt.plot(x, y1) 

plt.subplot(1, 2, 2) # 1행 2열로 2포지션
plt.plot(x, y2)

plt.show()

# %%
x = np.arange(1,10)
y1 = x * 5
y2 = x * 1
y3 = x * 0.3
y4 = x * 0.2

plt.subplot(2, 2, 1) # 2행 1열로 1포지션
plt.plot(x, y1) 

plt.subplot(2, 2, 2) # 2행 2열로 2포지션
plt.plot(x, y2)

plt.subplot(2, 2, 3) # 2행 2열로 2포지션
plt.plot(x, y3, color="red")

plt.subplot(2, 2, 4) # 2행 2열로 2포지션
plt.plot(x, y4)

plt.show()

# %% [markdown]
# - figure.add_subplot()

# %%
# 이것을 만들려면 figure 을 직접만들어야함
fig = plt.figure() # 강사님 스타일~ 
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.hist(np.random.randn(100), bins = 20)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
plt.show()

# %% [markdown]
# - plt.subplots()
#   - figure 과 axes 배열을 한 번에 반환
#   - 반복문과 함께 쓰기 좋고 가독성 뛰어남

# %%
fig, axes = plt.subplots(2, 2, figsize = (10,8))

axes[0,0].plot(np.random.rand(5))
axes[0,0].set_title("axes 1")

axes[0,1].plot(np.random.rand(5))
axes[0,1].set_title("axes 2")

axes[1,0].plot(np.random.rand(5))
axes[1,0].set_title("axes 3")

axes[1,1].plot(np.random.rand(5))
axes[1,1].set_title("axes 4")

plt.show()

# %% [markdown]
# # 데이터 시각화가 필요한 이유
#
# - 앤스콤 4분할 그래프 확인하기
#     - 앤스콤 4분할 데이터는 각각 평균, 분산, 상관관계, 회귀선이 모두 같음
#     - 따라서 수칫값만을 확인한다면 각각의 데이터는 모두 같다 라는 착각을 할 수 있음
#     - 하지만 시각화하면 모든 데이터 글룹들이 서로 다른 데이터 패턴을 가짐

# %%
anscombe = sns.load_dataset("anscombe")
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
# 평균 표준편차 계산

anscombe.groupby("dataset").agg(["mean","std"]).round(2)
# Out:
#            x          y
#         mean   std mean   std
# dataset
# I        9.0  3.32  7.5  2.03
# II       9.0  3.32  7.5  2.03
# III      9.0  3.32  7.5  2.03
# IV       9.0  3.32  7.5  2.03

# %%
# 똑같아!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
# 소수점이하가 차이난다고...한다...

# %%
# 시각화 하기
dataset_1 = anscombe[anscombe["dataset"] == "I"]
dataset_2 = anscombe[anscombe["dataset"] == "II"]
dataset_3 = anscombe[anscombe["dataset"] == "III"]
dataset_4 = anscombe[anscombe["dataset"] == "IV"]

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

#axes1.plot(dataset_1["x"], dataset_1["y"]) # 정확한표현이 안된다
axes1.plot(dataset_1["x"], dataset_1["y"], "o")
axes2.plot(dataset_2["x"], dataset_2["y"], "o")
axes3.plot(dataset_3["x"], dataset_3["y"], "o-")
axes4.plot(dataset_4["x"], dataset_4["y"], "o")

# supertitle : 전체제목이다.
fig.suptitle("Anscombe Data")

plt.show()

# %%
# 이것으로 시각화를 통해서 분석할수있는 데이터가 있다~라는것을 알수있다...
