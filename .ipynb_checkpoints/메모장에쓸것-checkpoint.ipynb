# %%
#
[import 할것]
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import folium 

[windows 용 한글 폰트 오류 해결]
from matplotlib import font_manager, rc

font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc("font", family = font_name)


(matplot)


1. 꺾은 선 그래프 (연속적으로 변화하는 데이터를 살펴보고자 할 때 주로 사용)



2. 막대 그래프 (집단별 차이를 표현할 때 주로 사용)

- 그룹 세로 막대 그래프

- 수평 막대 그래프

3. 산점도 (서로 다른 두 연속형 변수 사이의 관계를 나타내며 연속형 변수의 상관성을 확인할 때 산점도 그래프를 사용)

[2020년 건강검진 데이터 산점도 그래프¶]


- 키, 몸무게 산점도 그래프

4. 다변량 그래프 그리기 : 여러 변수들의 관계를 함께 보기 위해 사용

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# 산점도로 그리겠다~
ax.scatter(
    x = tips["total_bill"],
    y = tips["tip"],
    s = tips["size"],
    c = tips["color"], # 숫자로 변환하지 않으면 색깔의 범주가 아니라서 변환했다!!!
    #label="호호허"
)


5. 히스토그램 : 변수가 하나인 데이터의 빈도수를 막대 모양으로 나타낼 때 사용

# 분포!# 분포!# 분포!# 분포!# 분포!# 분포!# 분포!# 분포!# 분포!# 분포!


[건강검진 데이터 남성 키 히스토그램]

6. 그룹 히스토그램

7. 파이차트

8. 상자 수염 그래프


[건강 검진 데이터 남성 및 여성 키 상자수염 그래프]

----------------------------------------------------------------------------------
[seaborn]


1. 히스토그램

# 태도 : 같이보기 깊게보기

[건강검진 데이터 남성과 여성의 허리둘레 히스토그램]


2. count 그래프

[건강검진 데이터 count 그래프]



3. 산점도 그래프


4. 산점도와 히스토그램을 한번에 그리기

5. 이차원 밀집도

6. 박스 그래프

7. 바이올린 그래프 (분포를 더 잘 표현)

8. 관계 그래프 ( 컬럼,변수들의 관계들의 시각화를 보여준다 )


seaborn 스타일 설정

1. 선 그래프


df = df.ffill()
df.head()

df_seoul  = df_seoul.rename({"전입지별" : "전입지"}, axis = 1)
df_seoul.index
sr_gy = df_seoul.loc["경기도"]


[그래프 꾸미기]


2. 면적 그래프(area plot) : 각 열의 데이터를 선 그래프로 구현하는데, 선 그래프와 x 축 사이의 공간에 색이 입혀짐

3. 막대 그래프(bar plot)

- 보조 축

4. 산점도 : seaborn 이 좀더 쉽다 그랬나?

5. 히트맵 (2개의 범주형 변수를 각각 x축 , y 축에 놓고 데이터를 행렬 형태로 분류하여 시각화)

6. 범주형 데이터의 산점도 (산점도를 그릴때 데이터가 범주형이면 문제가 생길수있다)

7. 막대 그래프


8. 빈도 그래프 
별도의 전처리 없이 바로 컬럼을 넣을수있다!
hue 같은걸로 범주를 나눌수있다

9. 조인트 그래프
