# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# windows 용 한글 폰트 오류 해결
from matplotlib import font_manager, rc

font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc("font", family = font_name)

# %%
# 
kto_201001 = pd.read_excel("./data/trip/kto_201001.xlsx", 
                           usecols = "A:G", # 필요한 컬럼만 가져오기
                           header=1, 
                           skipfooter= 4
                          )

# %%
kto_201001
# Out:
#          국적      관광     상용   공용  유학/연수     기타       계
# 0      아시아주  329131  18238  421   4339  80916  433045
# 1        일본  202825   1750   89    549   3971  209184
# 2        대만   35788     41   17     37    516   36399
# 3        홍콩   13874     55    0     21    595   14545
# 4       마카오     554      0    0      0      0     554
# ..      ...     ...    ...  ...    ...    ...     ...
# 62  아프리카 기타     349    594   25     86    296    1350
# 63     기타대륙      10      3    0      0      0      13
# 64     국적미상      10      3    0      0      0      13
# 65     교포소계       0      0    0      0  22537   22537
# 66       교포       0      0    0      0  22537   22537
#
# [67 rows x 7 columns]

# %% [markdown]
# # 데이터 탐색
#
# - 데이터가 2010년 01월부터 2020년 5월까지 월별로 분할되어 있기 때문에 각각 월별로 데이터를 하나씩 가져와 하나의 테이블로 통합해야함

# %%
kto_201001.shape
# Out:
# (67, 7)

# %%
kto_201001.dtypes
# Out:
# 국적       object
# 관광        int64
# 상용        int64
# 공용        int64
# 유학/연수     int64
# 기타        int64
# 계         int64
# dtype: object

# %%
kto_201001.isna().sum()
# Out:
# 국적       0
# 관광       0
# 상용       0
# 공용       0
# 유학/연수    0
# 기타       0
# 계        0
# dtype: int64

# %%
kto_201001.describe()
# Out:
#                   관광            상용           공용        유학/연수            기타  \
# count      67.000000     67.000000    67.000000    67.000000     67.000000
# mean    11964.716418    683.462687    81.731343   152.776119   4115.910448
# std     47055.349998   2639.234303   370.034666   622.299519  11560.294887
# min         0.000000      0.000000     0.000000     0.000000      0.000000
# 25%       254.000000     23.500000     0.000000     6.000000    161.500000
# 50%       554.000000     47.000000     2.000000    17.000000    449.000000
# 75%      3638.000000    301.000000    14.000000    54.500000   1608.000000
# max    329131.000000  18238.000000  2159.000000  4339.000000  80916.000000
#
#                    계
# count      67.000000
# mean    16998.597015
# std     59189.624627
# min        13.000000
# 25%       605.000000
# 50%      1350.000000
# 75%      7582.000000
# max    433045.000000

# %%
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %% [markdown]
# - 평균적으로 관광 목적으로 가장 많은 외국인 이 입국함
# - 계를 제외한 모든 컬럼에서 최솟값이 0 임
#     - 확인 필요

# %%
(kto_201001[kto_201001["관광"] == 0] ) | (kto_201001[kto_201001["상용"] == 0]) |(kto_201001[kto_201001["공용"] == 0]) | (kto_201001[kto_201001["유학"] == 0]) | (kto_201001[kto_201001["기타"] == 0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for |: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 (kto_201001[kto_201001["관광"] == 0] ) | (kto_201001[kto_201001["상용"] == 0]) |(kto_201001[kto_201001["공용"] == 0]) | (kto_201001[kto_201001["유학"] == 0]) | (kto_201001[kto_201001["기타"] == 0])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:78, in OpsMixin.__or__(self, other)
#      76 @unpack_zerodim_and_defer("__or__")
#      77 def __or__(self, other):
# ---> 78     return self._logical_method(other, operator.or_)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:7913, in DataFrame._arith_method(self, other, op)
#    7910 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7912 with np.errstate(all="ignore"):
# -> 7913     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7914 return self._construct_result(new_data)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:7956, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7950     assert self.columns.equals(right.columns)
#    7951     # TODO: The previous assertion `assert right._indexed_same(self)`
#    7952     #  fails in cases with empty columns reached via
#    7953     #  _frame_arith_method_with_reindex
#    7954
#    7955     # TODO operate_blockwise expects a manager of the same type
# -> 7956     bm = self._mgr.operate_blockwise(
#    7957         # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7958         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7959         # "ArrayManager"
#    7960         # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    7961         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7962         # "BlockManager"
#    7963         right._mgr,  # type: ignore[arg-type]
#    7964         array_op,
#    7965     )
#    7966     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7968 elif isinstance(right, Series) and axis == 1:
#    7969     # axis=1 means we want to operate row-by-row
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1511, in BlockManager.operate_blockwise(self, other, array_op)
#    1507 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1508     """
#    1509     Apply array_op blockwise with another (aligned) BlockManager.
#    1510     """
# -> 1511     return operate_blockwise(self, other, array_op)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:454, in logical_op(left, right, op)
#     450 else:
#     451     # i.e. scalar
#     452     is_other_int_dtype = lib.is_integer(rvalues)
# --> 454 res_values = na_logical_op(lvalues, rvalues, op)
#     456 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     457 #   integer dtypes.  Otherwise these are boolean ops
#     458 if not (left.dtype.kind in "iu" and is_other_int_dtype):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:369, in na_logical_op(x, y, op)
#     367     x = ensure_object(x)
#     368     y = ensure_object(y)
# --> 369     result = libops.vec_binop(x.ravel(), y.ravel(), op)
#     370 else:
#     371     # let null fall thru
#     372     assert lib.is_scalar(y)
#
# File ops.pyx:252, in pandas._libs.ops.vec_binop()
#
# File ops.pyx:245, in pandas._libs.ops.vec_binop()
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %% [markdown]
# - 교포소계와 교포는 4개 컬럼이 모두 0

# %% [markdown]
# ## 기준 연월 추가
# - 각 월별 데이터가 추가될 예정이기 때문에 각 데이터마다 기준 연월 정보가 추가되어야함

# %%
kto_201001["기준연월"] = "2010-01"

# %%
kto_201001
# Out:
#          국적      관광     상용   공용  유학/연수     기타       계     기준연월
# 0      아시아주  329131  18238  421   4339  80916  433045  2010-01
# 1        일본  202825   1750   89    549   3971  209184  2010-01
# 2        대만   35788     41   17     37    516   36399  2010-01
# 3        홍콩   13874     55    0     21    595   14545  2010-01
# 4       마카오     554      0    0      0      0     554  2010-01
# ..      ...     ...    ...  ...    ...    ...     ...      ...
# 62  아프리카 기타     349    594   25     86    296    1350  2010-01
# 63     기타대륙      10      3    0      0      0      13  2010-01
# 64     국적미상      10      3    0      0      0      13  2010-01
# 65     교포소계       0      0    0      0  22537   22537  2010-01
# 66       교포       0      0    0      0  22537   22537  2010-01
#
# [67 rows x 8 columns]

# %% [markdown]
# ## 국적 확인

# %%
kto_201001["국적"].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %% [markdown]
# - 아시아주, 미주, 교포소계등 국가가 아닌 값이 포함되어 있음

# %%
contents_list = ["아시아주", "미주", "구주", "대양주","아프리카주", "기타대륙", "교포소계"]

# %%
kto_201001_country = kto_201001[kto_201001["국적"].isin(contents_list) == False]

# %%
kto_201001_country
# Out:
#           국적      관광     상용    공용  유학/연수     기타       계     기준연월     대륙  \
# 1         일본  202825   1750    89    549   3971  209184  2010-01    아시아
# 2         대만   35788     41    17     37    516   36399  2010-01    아시아
# 3         홍콩   13874     55     0     21    595   14545  2010-01    아시아
# 4        마카오     554      0     0      0      0     554  2010-01    아시아
# 5         태국   13374     39    13     53   4335   17814  2010-01    아시아
# 6      말레이시아    3292     61     0     49   1157    4559  2010-01    아시아
# 7        필리핀    3984    219   104     87  16820   21214  2010-01    아시아
# 8      인도네시아    1840    327     3     65   2826    5061  2010-01    아시아
# 9       싱가포르    4201    120     3     27   1017    5368  2010-01    아시아
# 10       미얀마     630     18    54     10   3882    4594  2010-01    아시아
# 11       베트남    1384    284    21    150   2676    4515  2010-01    아시아
# 12        인도    1646   1387     7     68   2918    6026  2010-01    아시아
# 13      스리랑카      39     28     2     13    566     648  2010-01    아시아
# 14      파키스탄      70    200     1     41    402     714  2010-01    아시아
# 15     방글라데시      86     84     9     42    489     710  2010-01    아시아
# 16      캄보디아     102     22     0     25    131     280  2010-01    아시아
# 17        몽골    2333    234     6    197    554    3324  2010-01    아시아
# 18        중국   40425  11930    55   2751  36091   91252  2010-01    아시아
# 19        이란      69    309     0      3    217     598  2010-01    아시아
# 20      이스라엘     792     11     0      0     53     856  2010-01    아시아
# 21        터키     472     15     2     15    465     969  2010-01    아시아
# 22    우즈베키스탄     190    293    17     40    740    1280  2010-01    아시아
# 23     카자흐스탄     238     48     4     22    107     419  2010-01    아시아
# 24       GCC     223    134     0     18     55     430  2010-01    아시아
# 25    아시아 기타     700    629    14     56    333    1732  2010-01   아메리카
# 27        미국   26943   1195  2145    135  12647   43065  2010-01   아메리카
# 28       캐나다    4912     96     4     21   3743    8776  2010-01   아메리카
# 29       멕시코     252     29     1      4     93     379  2010-01   아메리카
# 30       브라질     459     46     1     11    248     765  2010-01     유럽
# 31     미주 기타     501     25     8     29    291     854  2010-01     유럽
# 33        영국    5746    383     4     20   1368    7521  2010-01     유럽
# 34        독일    5838    255    24     68   1458    7643  2010-01     유럽
# 35       프랑스    3019    343    44    115   1145    4666  2010-01     유럽
# 36      네덜란드    1205     47     1     20    449    1722  2010-01     유럽
# 37       스웨덴     579     63     5     17    185     849  2010-01     유럽
# 38       스위스     512     30     0      7     77     626  2010-01     유럽
# 39      이탈리아    1157     40    12     12    155    1376  2010-01     유럽
# 40       덴마크     378     28     0      5     94     505  2010-01     유럽
# 41      노르웨이     517    274     0      6    149     946  2010-01     유럽
# 42       벨기에     322     25     1      8    104     460  2010-01     유럽
# 43     오스트리아     440     13     2      9    141     605  2010-01     유럽
# 44       스페인     542     29    11      8    108     698  2010-01     유럽
# 45       그리스     345     47     0      0    213     605  2010-01     유럽
# 46      포르투갈     256      9     0      1     44     310  2010-01     유럽
# 47       핀란드     376     16     0     12    131     535  2010-01     유럽
# 48      아일랜드     311     16     0      1    198     526  2010-01     유럽
# 49     우크라이나     386     29     0      6   1515    1936  2010-01     유럽
# 50       러시아    4861    505    15     83   5409   10873  2010-01     유럽
# 51     크로아티아     166     20     0      1    298     485  2010-01     유럽
# 52      루마니아     142     12     0      9    370     533  2010-01     유럽
# 53      불가리아     103      0     0      9    414     526  2010-01  오세아니아
# 54       폴란드     378     29     0     10    431     848  2010-01  오세아니아
# 55     구주 기타    1219     37     0     49    410    1715  2010-01  오세아니아
# 57   오스트레일리아    6974    340     9     10   1098    8431  2010-01   아프리카
# 58      뉴질랜드    1545     53     1      1    435    2035  2010-01   기타대륙
# 59    대양주 기타     730      0     4      4    168     906  2010-01   기타대륙
# 61  남아프리카공화국     214     27     0      2    545     788  2010-01   기타대륙
# 62   아프리카 기타     349    594    25     86    296    1350  2010-01   기타대륙
# 64      국적미상      10      3     0      0      0      13  2010-01   기타대륙
# 66        교포       0      0     0      0  22537   22537  2010-01     교포
#
#     관광객비율(%)
# 1       97.0
# 2       98.3
# 3       95.4
# 4      100.0
# 5       75.1
# 6       72.2
# 7       18.8
# 8       36.4
# 9       78.3
# 10      13.7
# 11      30.7
# 12      27.3
# 13       6.0
# 14       9.8
# 15      12.1
# 16      36.4
# 17      70.2
# 18      44.3
# 19      11.5
# 20      92.5
# 21      48.7
# 22      14.8
# 23      56.8
# 24      51.9
# 25      40.4
# 27      62.6
# 28      56.0
# 29      66.5
# 30      60.0
# 31      58.7
# 33      76.4
# 34      76.4
# 35      64.7
# 36      70.0
# 37      68.2
# 38      81.8
# 39      84.1
# 40      74.9
# 41      54.7
# 42      70.0
# 43      72.7
# 44      77.7
# 45      57.0
# 46      82.6
# 47      70.3
# 48      59.1
# 49      19.9
# 50      44.7
# 51      34.2
# 52      26.6
# 53      19.6
# 54      44.6
# 55      71.1
# 57      82.7
# 58      75.9
# 59      80.6
# 61      27.2
# 62      25.9
# 64      76.9
# 66       0.0

# %%
# 인덱스 초기화
kto_201001_country = kto_201001_country.reset_index(drop=True)

# %%
kto_201001_country.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준연월
# 0   일본  202825  1750  89    549  3971  209184  2010-01
# 1   대만   35788    41  17     37   516   36399  2010-01
# 2   홍콩   13874    55   0     21   595   14545  2010-01
# 3  마카오     554     0   0      0     0     554  2010-01
# 4   태국   13374    39  13     53  4335   17814  2010-01

# %%
# 대륙컬럼을 추가하면...
# 각 대륙별 데이터 개수 파악
kto_201001[kto_201001["국적"].isin(contents_list)]
# Out:
#        국적      관광     상용    공용  유학/연수     기타       계     기준연월    대륙  관광객비율(%)
# 0    아시아주  329131  18238   421   4339  80916  433045  2010-01   아시아      76.0
# 26     미주   33067   1391  2159    200  17022   53839  2010-01  아메리카      61.4
# 32     구주   28798   2250   119    476  14866   46509  2010-01    유럽      61.9
# 56    대양주    9249    393    14     15   1701   11372  2010-01  아프리카      81.3
# 60  아프리카주     563    621    25     88    841    2138  2010-01  기타대륙      26.3
# 63   기타대륙      10      3     0      0      0      13  2010-01  기타대륙      76.9
# 65   교포소계       0      0     0      0  22537   22537  2010-01  기타대륙       0.0

# %% [markdown]
# - 대륙 컬럼의 내용은 순서대로 아시아 25개, 미주 5개, 유럽 23개, 오세아니아 3개, 아프리카 2개, 기타 1개, 교포 1개

# %%
continents = ["아시아"] * 25 + ["아메리카"] * 5 + ["유럽"] * 23 + ["오세아니아"] * 3 + ["아프리카"] * 2 + ["기타대륙"] * 1 + ["교포"] * 1

# %%
kto_201001_country["대륙"] = continents

# %% [markdown]
# ## 국적별 관광객 비율

# %%
kto_201001_country["관광객비율(%)"] = round((kto_201001["관광"] /  kto_201001["계"]) * 100 , 1)

# %%
kto_201001_country
# Out:
#           국적      관광     상용    공용  유학/연수     기타       계     기준연월     대륙  \
# 0         일본  202825   1750    89    549   3971  209184  2010-01    아시아
# 1         대만   35788     41    17     37    516   36399  2010-01    아시아
# 2         홍콩   13874     55     0     21    595   14545  2010-01    아시아
# 3        마카오     554      0     0      0      0     554  2010-01    아시아
# 4         태국   13374     39    13     53   4335   17814  2010-01    아시아
# 5      말레이시아    3292     61     0     49   1157    4559  2010-01    아시아
# 6        필리핀    3984    219   104     87  16820   21214  2010-01    아시아
# 7      인도네시아    1840    327     3     65   2826    5061  2010-01    아시아
# 8       싱가포르    4201    120     3     27   1017    5368  2010-01    아시아
# 9        미얀마     630     18    54     10   3882    4594  2010-01    아시아
# 10       베트남    1384    284    21    150   2676    4515  2010-01    아시아
# 11        인도    1646   1387     7     68   2918    6026  2010-01    아시아
# 12      스리랑카      39     28     2     13    566     648  2010-01    아시아
# 13      파키스탄      70    200     1     41    402     714  2010-01    아시아
# 14     방글라데시      86     84     9     42    489     710  2010-01    아시아
# 15      캄보디아     102     22     0     25    131     280  2010-01    아시아
# 16        몽골    2333    234     6    197    554    3324  2010-01    아시아
# 17        중국   40425  11930    55   2751  36091   91252  2010-01    아시아
# 18        이란      69    309     0      3    217     598  2010-01    아시아
# 19      이스라엘     792     11     0      0     53     856  2010-01    아시아
# 20        터키     472     15     2     15    465     969  2010-01    아시아
# 21    우즈베키스탄     190    293    17     40    740    1280  2010-01    아시아
# 22     카자흐스탄     238     48     4     22    107     419  2010-01    아시아
# 23       GCC     223    134     0     18     55     430  2010-01    아시아
# 24    아시아 기타     700    629    14     56    333    1732  2010-01    아시아
# 25        미국   26943   1195  2145    135  12647   43065  2010-01   아메리카
# 26       캐나다    4912     96     4     21   3743    8776  2010-01   아메리카
# 27       멕시코     252     29     1      4     93     379  2010-01   아메리카
# 28       브라질     459     46     1     11    248     765  2010-01   아메리카
# 29     미주 기타     501     25     8     29    291     854  2010-01   아메리카
# 30        영국    5746    383     4     20   1368    7521  2010-01     유럽
# 31        독일    5838    255    24     68   1458    7643  2010-01     유럽
# 32       프랑스    3019    343    44    115   1145    4666  2010-01     유럽
# 33      네덜란드    1205     47     1     20    449    1722  2010-01     유럽
# 34       스웨덴     579     63     5     17    185     849  2010-01     유럽
# 35       스위스     512     30     0      7     77     626  2010-01     유럽
# 36      이탈리아    1157     40    12     12    155    1376  2010-01     유럽
# 37       덴마크     378     28     0      5     94     505  2010-01     유럽
# 38      노르웨이     517    274     0      6    149     946  2010-01     유럽
# 39       벨기에     322     25     1      8    104     460  2010-01     유럽
# 40     오스트리아     440     13     2      9    141     605  2010-01     유럽
# 41       스페인     542     29    11      8    108     698  2010-01     유럽
# 42       그리스     345     47     0      0    213     605  2010-01     유럽
# 43      포르투갈     256      9     0      1     44     310  2010-01     유럽
# 44       핀란드     376     16     0     12    131     535  2010-01     유럽
# 45      아일랜드     311     16     0      1    198     526  2010-01     유럽
# 46     우크라이나     386     29     0      6   1515    1936  2010-01     유럽
# 47       러시아    4861    505    15     83   5409   10873  2010-01     유럽
# 48     크로아티아     166     20     0      1    298     485  2010-01     유럽
# 49      루마니아     142     12     0      9    370     533  2010-01     유럽
# 50      불가리아     103      0     0      9    414     526  2010-01     유럽
# 51       폴란드     378     29     0     10    431     848  2010-01     유럽
# 52     구주 기타    1219     37     0     49    410    1715  2010-01     유럽
# 53   오스트레일리아    6974    340     9     10   1098    8431  2010-01  오세아니아
# 54      뉴질랜드    1545     53     1      1    435    2035  2010-01  오세아니아
# 55    대양주 기타     730      0     4      4    168     906  2010-01  오세아니아
# 56  남아프리카공화국     214     27     0      2    545     788  2010-01   아프리카
# 57   아프리카 기타     349    594    25     86    296    1350  2010-01   아프리카
# 58      국적미상      10      3     0      0      0      13  2010-01   기타대륙
# 59        교포       0      0     0      0  22537   22537  2010-01     교포
#
#     관광객비율(%)
# 0       76.0
# 1       97.0
# 2       98.3
# 3       95.4
# 4      100.0
# 5       75.1
# 6       72.2
# 7       18.8
# 8       36.4
# 9       78.3
# 10      13.7
# 11      30.7
# 12      27.3
# 13       6.0
# 14       9.8
# 15      12.1
# 16      36.4
# 17      70.2
# 18      44.3
# 19      11.5
# 20      92.5
# 21      48.7
# 22      14.8
# 23      56.8
# 24      51.9
# 25      40.4
# 26      61.4
# 27      62.6
# 28      56.0
# 29      66.5
# 30      60.0
# 31      58.7
# 32      61.9
# 33      76.4
# 34      76.4
# 35      64.7
# 36      70.0
# 37      68.2
# 38      81.8
# 39      84.1
# 40      74.9
# 41      54.7
# 42      70.0
# 43      72.7
# 44      77.7
# 45      57.0
# 46      82.6
# 47      70.3
# 48      59.1
# 49      19.9
# 50      44.7
# 51      34.2
# 52      26.6
# 53      19.6
# 54      44.6
# 55      71.1
# 56      81.3
# 57      82.7
# 58      75.9
# 59      80.6

# %%
# 관광객 비율 컬럼으로 내림차순 정렬
kto_201001.sort_values("관광객비율(%)", ascending = False)
# Out:
#       국적      관광    상용  공용  유학/연수     기타       계     기준연월    대륙  관광객비율(%)
# 4    마카오     554     0   0      0      0     554  2010-01   아시아     100.0
# 2     대만   35788    41  17     37    516   36399  2010-01   아시아      98.3
# 1     일본  202825  1750  89    549   3971  209184  2010-01   아시아      97.0
# 3     홍콩   13874    55   0     21    595   14545  2010-01   아시아      95.4
# 20  이스라엘     792    11   0      0     53     856  2010-01   아시아      92.5
# ..   ...     ...   ...  ..    ...    ...     ...      ...   ...       ...
# 19    이란      69   309   0      3    217     598  2010-01   아시아      11.5
# 14  파키스탄      70   200   1     41    402     714  2010-01   아시아       9.8
# 13  스리랑카      39    28   2     13    566     648  2010-01   아시아       6.0
# 65  교포소계       0     0   0      0  22537   22537  2010-01  기타대륙       0.0
# 66    교포       0     0   0      0  22537   22537  2010-01    교포       0.0
#
# [67 rows x 10 columns]

# %%
# 오름차순
kto_201001.sort_values("관광객비율(%)")
# Out:
#       국적      관광    상용  공용  유학/연수     기타       계     기준연월    대륙  관광객비율(%)
# 66    교포       0     0   0      0  22537   22537  2010-01    교포       0.0
# 65  교포소계       0     0   0      0  22537   22537  2010-01  기타대륙       0.0
# 13  스리랑카      39    28   2     13    566     648  2010-01   아시아       6.0
# 14  파키스탄      70   200   1     41    402     714  2010-01   아시아       9.8
# 19    이란      69   309   0      3    217     598  2010-01   아시아      11.5
# ..   ...     ...   ...  ..    ...    ...     ...      ...   ...       ...
# 20  이스라엘     792    11   0      0     53     856  2010-01   아시아      92.5
# 3     홍콩   13874    55   0     21    595   14545  2010-01   아시아      95.4
# 1     일본  202825  1750  89    549   3971  209184  2010-01   아시아      97.0
# 2     대만   35788    41  17     37    516   36399  2010-01   아시아      98.3
# 4    마카오     554     0   0      0      0     554  2010-01   아시아     100.0
#
# [67 rows x 10 columns]

# %%
# 대륙별 관광객 비율

kto_201001.groupby("대륙")["관광객비율(%)"].mean()
# Out:
# 대륙
# 교포        0.000000
# 기타대륙     48.712500
# 아메리카     57.380000
# 아시아      50.968000
# 아프리카     82.000000
# 오세아니아    45.100000
# 유럽       62.895652
# Name: 관광객비율(%), dtype: float64

# %% [markdown]
# - 내가 값을 잘못냈지만... 일단 강사님쪽에서는 오세아니아의 비율이 높음
#
# - 관광목적으로 방문하는 외국인은 26.6% 뿐임
#
# - 아시아의 관광객 비율은 49.5%로 유럽보다 나듬
#
# - 소득수준이 낮은 국가에서는 관광 목적으로 방문하는 외국인 비율이 낮은 것으로 보임

# %%
kto_201001[kto_201001["국적"] == "중국"]
# Out:
#     국적     관광     상용  공용  유학/연수     기타      계     기준연월   대륙  관광객비율(%)
# 18  중국  40425  11930  55   2751  36091  91252  2010-01  아시아      44.3

# %%
# 관광관련 팡생변수 만든것임
# 내일 전처리...
